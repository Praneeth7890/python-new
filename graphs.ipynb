# %% [markdown]
# <a href="https://colab.research.google.com/github/Praneeth7890/python-new/blob/module-04/graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0,10])
ypoints = np.array([0,500])

plt.scatter(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A","B","C","D","E"])
y = np.array([4,6,8,10,12])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as pyplot
import numpy as np

x = np.array(["che","clad","csen1001","csen1011","mat1001","mat1011","mech1021","vdc"])
y = np.array([89,97,95,78,69,59,97,58])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as pyplot
import numpy as np

x = np.array(["che","clad","csen1001","csen1011","mat1001","mat1011","mech1021","vdc"])
y = np.array([89,97,95,78,69,59,97,58])

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as pyplot
import numpy as np

x = np.array(["che","clad","csen1001","csen1011","mat1001","mat1011","mech1021","vdc"])
y = np.array([89,97,95,78,69,59,97,58])

plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as pyplot
import numpy as np

x = np.array(["che","clad","csen1001","csen1011","mat1001","mat1011","mech1021","vdc"])
y = np.array([89,97,95,78,69,59,97,58])

plt.plot(x,y)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["che","clad","csen1001","csen1011","mat1001","mat1011","mech1021","vdc"])
y = np.array([89,97,95,78,69,59,97,58])

plt.bar(x,y)

plt.xlabel1("subjects")
plt.ylabel1("marks")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-4c897e211807> in <module>()
#       7 plt.bar(x,y)
#       8
# ----> 9 plt.xlabel1("subjects")
#      10 plt.ylabel1("marks")
#      11
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlabel1'

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 25, 25, 15])
x = ["GT650", "RC390", "Duke 390", "R15"]
xexplode = [0.2, 0.2, 0.2, 1.0]
plt.pie(y, labels = x,explode = xexplode)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([40,28,49,37])
x = ["GT650", "RC390", "Duke 390", "R15"]
z = [0.2,0,0.2,0]

plt.pie(y, labels = x, explode = z, shadow = True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([40,28,49,37])
x = ["GT650", "RC390", "Duke 390", "R15"]
z = ["black", "hotpink", "b", "#4CAF50"]


plt.pie(y, labels = x, colors = z)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([25,36,26,46])

plt.plot(ypoints, 'o:r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'D', ms = 30)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'D', ms = 30, mec = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linewidth = '20.5')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "red")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A","B","C","D"])
y = np.array([34,46,84,32])

plt.bar(x,y , color ="yellow")
plt.show()

# %% [markdown]
# exam

# %%
import matplotlib.pyplot as plt

import numpy as np 



x = np.array(["cse","mech","civil","ece"])

y = np.array([50,40,30,20])


plt.pie(x,y)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-ebe835955a89> in <module>()
#      10
#      11
# ---> 12 plt.pie(x,y)
#      13
#      14 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2753         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2754         frame=frame, rotatelabels=rotatelabels, **({"data": data} if
# -> 2755         data is not None else {}))
#    2756
#    2757
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# ...

# %%
import matplotlib.pyplot as plt

import numpy as np 



hours = np.array([1,2,3,4])

subjects = np.array(["english","python","maths","chemistry"])



plt.scatter(hours,subjects)

plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np 



x = np.array([3,8,1,10])



plt.plot(x)

plt.show()

# %%
import matplotlib.pyplot as plt 

import numpy as np

y =np.array([35,25,25,15])

mylabels = ["Python", "Maths", "English", "chemistry"]

myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode) 

plt.show()
